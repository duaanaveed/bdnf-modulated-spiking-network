# %%
from brian2 import *
from pathlib import Path
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt

(Path(directory := "STDP_homeostatic_high_epoh_never_test")).mkdir(parents=True, exist_ok=True)

images = list()
for folder in [
    Path("/Users/duaanaveed/Downloads/archive/training/shapes/train/circle"),
    Path("/Users/duaanaveed/Downloads/archive/training/shapes/train/square"),
    Path("/Users/duaanaveed/Downloads/archive/training/shapes/train/triangle"),
]:
    for file in folder.iterdir():
        if file.name.startswith('.'):
            print("  Skipped (not file or hidden)")
            continue
        if not file.is_file():
            print("  Skipped (not a file)")
            continue

        print("Found:", file.name)

        if file.suffix.lower() not in ['.png']:
            print("  Skipped (unsupported type)")
            continue

        try:
            img = iio.imread(file)                # read image into numpy array (grayscale expected)
            images.append(img)                    # save it for later
            print("  Loaded successfully")
        except Exception as e:
            print(f"  Skipped {file.name}: {e}")

print(f"\nTotal images loaded: {len(images)}")

# convert image to floats in [0,1] range
def normalize01(img):
    img = img.astype(float)   # make sure math works in float(not integers)
    # if pixel values = 0-255, scale down to 0-1
    if img.max() > 1.0:
        img = img / 255.0
    return img                      

# normalisation for every loaded image: mimics biology: real neurons don’t receive unlimitedly sized/strengthened signals,inputs(synaptic currents)naturally bounded
H, W  = imgs[0].shape   # takes image height+width from first image
Npix  = H * W           # total number of pixels per image = one neuron per pixel in input layer
# each input neuron=photoreceptors (light-sensing cells) covering some region of retina=one ganglion cell/lateral geniculate nucleus cells sends spikes about brightness=how bright that patch=how fast neuron fires
# retinotopic map(the receptive field images generated at the end)= retina + early visual cortex preserve spatial layout of image

labels = np.array([0]*15 + [1]*15 + [2]*15) # explicitly saying which neuron should spike= mimics biology:reward prediction errors

# image encoding - real neurons change continuously, network only calculates in small increments
defaultclock.dt = 1*ms     # virtual brain moves forward every 1 ms each time equations are updated after recalculating all variables
Ton, Tisi = 300*ms, 50*ms  # stimulus duration per image (Ton) + a short quiet period after (Tisi) (whole network level)
epochs    = 5              # how many passes over the whole dataset (do i explain why here?)
max_rate  = 10*Hz          # max firing rate for input neurons (upper bound for pixel→rate mapping) mimics biological firing limit for sensory neurons
                           # real neurons cant/dont fire infinitely fast (biological limit:refractory period(for input neurons)-brief recovery time after each spike)

def img_to_rates(img):
    return (1.0 - img.flatten()) * max_rate  #flips brightness so dark=high firing rate (close to 10 Hz); pixel dark (close to 1), rate might be close to max_rate, if pixel light (close to 0), rate might be near 0 Hz per ton
    # report you having to do this
    #return (img.flatten()) * max_rate

# poisson input layer 
IN = PoissonGroup(Npix, rates=0*Hz)  # generates spikes randomly at an average rate, starts off silent. if pixel is dark - more excitability; if light - less excitability
                                            # each neuron fires around an average rate, but precise spike times wander randomly around that average, exact intervals between spikes vary trial to trial
# mimics biology: neurons fire noisily w randomness, adding poisson=adding randomness+jitters
    #noise being: molecules drifting in n out of ion channels, random neurotransmitter release, differences in membrane potential,background signals from other neurons
# if i dont do poisson how does it train? does it think the first 15 will be circle based on order, will it memorise the rhythm instead?

# output layer w/ teacher bias
tau_m = 20*ms       # membrane time constant:controls how fast neuron voltage changes over time; mimics biology:in real neurons-depends on cell size+electrical properties
v_rest = 0*ms       # resting voltage of neuron (its idle state) mimics biology as resting neuron potential is -70mV
v_thr = 4*mV        # how high voltage climbs to trigger spike (neuron sensitivity/depolarisation) once internal voltage crosses this (spike), neuron sends an output spike to the next layer
v_reset = 0*mV      # after neuron fires spike, instantly reset voltage to this (repolarisation); mimics biology via how biological neurons “discharge” after firing|its zero bc the difference of change matters, not exact numbers
tau_e = 5*ms        # ge (excitation signal-makes neuron more likely to fire) how quickly excitation fades inside neuron after spike; quick excitement fading almost immediately
tau_i = 10*ms       # gi (inhibition signal-makes it less likely to fire) how quickly inhibition fades inside neuron after spike;stronger inhibition lasting longer
# no hyperpolarisation 

# “leaky integrate-and-fire” neuron equation w separate excitatory (ge)+inhibitory (gi) currents 
eqs_out = '''
dv/dt  = (-(v - v_rest) + ge - gi + Iteach) / tau_m : volt # describes how neuron voltage changes over time in model. voltage always trying to go back to rest, excitatory inputs push it up, inhibitory ones pull it down, teacher adds bias
dge/dt = -ge/tau_e : volt                                  # excitatory current decaying over time; rate of change of ge proportional to how big ge is, but in opposite direction (negative), mimics biology: temporary effect of excitatory neurotransmitters (ie: glutamate), wave of currrent:presynaptic neuron spikes=releases transmitter,receiving neuron excitatory channels open briefly(jump in ge)=they close=effect fades=decay
dgi/dt = -gi/tau_i : volt                                  # inhibitory current decaying over time; neuron stays suppressed for 10 ms after inhibitory spike, mimics biology: inhibitory neurotransmitters (like GABA) usually act a bit longer than excitatory,GABA opens channels that let negative ions (ie: Cl-) flow in=makes inside of neuron more negative=less likely to fire, after a few milliseconds, channels close, neuron returns to normal
Iteach : volt                                              # teaching current: small temporary electrical nudge added to right output neuron whenever image is shown to help it fire accordingly; makes it a little easier for neuron to reach threshold+fire during training; mimics biology: neuromodulators(ie:dopamine, acetylcholine, serotonin) that temporarily boost certain neurons when brain gets feedback/reward
s : integer                                                # keeps track of how many times neuron has spiked+stores whole numbers, shows which output neuron fires most-that becomes its prediction; mimics biology via firing rate (how many spikes per second a neuron emits to quantifying how strongly it’s responding to stimulus) 

'''

OUT = NeuronGroup(
    N=3, model=eqs_out,         # build 3 output neurons using model above
    threshold='v>v_thr',        # when v crosses threshold, neuron spikes
    reset='v=v_reset; s += 1',  # after spike, reset voltage+spike counter  
    refractory=6*ms,            # small no-spike period after each spike, mimics biology: a form of hyperpolarisation without becoming more negative-neuron is locked during recovery; immediately after, na+ channels inactivate(physically closed,won’t reopen right away) simultaneously, k+ channels open, pushing k+ ions out to bring voltage back down, until both channels reset, neuron cant produce another spike
    method='euler'              # “step-by-step” method; lets digital neuron change smoothly over simulated time=same way a real neuron’s voltage changes smoothly in real time; brian2 has different solvers for advancing time
)

OUT.v = v_rest                     # resets every neuron’s voltage to resting level, so none start w charge
if hasattr(OUT, 'ge'): OUT.ge = 0  # sets all excitatory currents to zero
if hasattr(OUT, 'gi'): OUT.gi = 0  # sets all inhibitory currents to zero
# hasattr basically checks if the neuron group has the variable, and if it does to make sure its at zero
# mimics biology: real neurons do similarly between stimuli=reset membrane voltage back toward resting potential,excitatory+inhibitory currents decay,by the time next signal comes, neuron is ready to respond cleanly

# BDNF profiles (my own variables)
BDNF_PROFILES = {      #have it show output of its prediction process, also could tell it that the inverse and the regular image means the same thing.
    "low": {
        "eta_scale": 0.5,     # overall learning speed/plasticity; mimics biology: higher BDNF signaling often raises plasticity “gains”(synapses change more from same activity), lower BDNF dampens
        "ltp_scale": 0.8,     # connection between two neurons gets stronger: easier to activate in future
        "ltd_scale": 1.1,     # connection between two neurons gets weaker: harder to activate in future; is often reduced when BDNF is high
        "norm_every": 1,      # normalise every x epochs; synaptic scaling (gina turrigiano):neurons globally scale all synapses up/down to maintain target firing rate, if cell fires too much=proportionally downscales all excitatory weights, if too silent = upscales
    },
    "medium": {
        "eta_scale": 1.0,
        "ltp_scale": 1.0,
        "ltd_scale": 1.0,
        "norm_every": 2,
    },
    "high": {
        "eta_scale": 1.5,
        "ltp_scale": 1.2,     
        "ltd_scale": 0.9,     
        "norm_every": 3,
    },
    "high_homeostatic": {
        "eta_scale": 1.3,      # still elevated plasticity, but dampened slightly
        "ltp_scale": 1.1,      # balanced potentiation
        "ltd_scale": 0.95,     # nearly symmetric depression
        "norm_every": 3, 
    },
}

BDNF_LEVEL = "high_homeostatic" 

# mimic biology: ltd/ltp dependent on low/high ca+ respectively, travelling into postsynaptic neuron through NMDA receptors.

# base STDP: default learning behaviour before BDNF profile variables
eta_base   = 0.02        # how fast learning happens overall for both ltd/ltp; mimics biology:how chemically “plastic” neuron is,how readily its synapses strengthen/weaken during activity,neuromodulators/BDNF raise/lower this
Apre_base  = 0.015       # how strong strengthening events are, makes ltp opportunity larger bc apre is what postsynaptic event uses to increase w; mimics biology: how strongly presynaptic event “primes” synapse for strengthening/ltp if postsynaptic cell fires right after(ie: more glutamate/NMDA-driven Ca²⁺ signal ready to trigger ltp)
Apost_base = -0.016      # how strong weakening events are; biases base model slightly toward ltd but is countered by BDNF scaling+teacher bias; mimics biology: ie. ca2+ pattern favoring phosphatases=receptor removal=ltd if pre activity follows too late

# apply BDNF profile
_bd = BDNF_PROFILES[BDNF_LEVEL]
eta   = eta_base  * _bd["eta_scale"]
Apre  = Apre_base * _bd["ltp_scale"]      # memory of when the input neuron last fired
Apost = Apost_base* _bd["ltd_scale"]      # memory of when the output neuron last fired

norm_every = _bd["norm_every"]
print(f"[BDNF={BDNF_LEVEL}] eta={eta:.4f}, Apre={Apre:.4f}, Apost={Apost:.4f}, norm_every={norm_every}")

taupre  = 10*ms  # how long input neuron’s trace lasts after spike; apre still positive when post spike happens=LTP (weight goes up)
taupost = 10*ms  # how long output neuron’s trace lasts after spike; apost (negative) still present when pre spike happens=LTD (weight goes down).
# mimics biology: chemical signals (ie: ca2+) rise briefly after spikes then decay over a few ms-that decides whether connection strengthens/weakens
wmax    = 0.05   # ceiling for each synapse’s strength, weights can’t exceed this value, prevents synapses from growing w/out bound+dominating everything; mimics biology:real synapses have physical/biochemical limits (ie: limited receptors can be packed in, limited vesicles can release etc)
wscale  = 5*mV   # converts dimensionless weight w into actual voltage kick on postsynaptic neuron when an input spike occurs, how strongly each presynaptic spike affects postsynaptic neuron: by releasing neurotransmitters at a synapse=bind to receptors=cause a change in postsynaptic neuron membrane potential

S = Synapses(IN, OUT,                                  # represents the synapase between the pre-synaptic & post-synaptic neuron, the strength of the connection between the two
    model='''
        w : 1                                          # strength/scaling factor' weight meaning the strength of that connection, 30000 separate weights values; mimics biology: synaptic efficacy - how much presynaptic neuron’s spike changes voltage of postsynaptic neuron, bigger w = more neurotransmitter released/more receptors = stronger effect
        dapre/dt  = -apre/taupre  : 1 (event-driven)   # pre-trace decays over time, event-driven means it only updates when there's a spike; mimics biology: chemical trace left behind in synapse after presynaptic neuron fires, few milliseconds of elevated neurotransmitter/intracellular signaling (ie: short-lived glutamate/presynaptic ca2+)
        dapost/dt = -apost/taupost : 1 (event-driven)  # post-trace decays over time; mimics biology: temporary rise in ca2+/activation of signaling enzymes right after postsynaptic neuron fires
    ''', #
    on_pre=''' 
        ge_post += w * wscale                          # add an amount of excitatory conductance to postsynaptic neuron equal to this synapse’s strength (w) times scaling factor (wscale); mimics biology: neurotransmitter release: spike opens channels on postsynaptic neuron, letting positive ions flow in: small excitatory voltage bump            
        apre += Apre                                   # when presynaptic neuron spikes, pre-trace gets little bump, apre=size of that bump; mimic biology: presynaptic terminal now “remembers” it just fired (ie: ca2+ entering termina/vesicle release probability increases)
        w = clip(w + eta*apost, 0, wmax)               # adjust synaptic weight using postsynaptic trace (apost)xlearning rate+w that’s still lingering from recent postsynaptic spikes, using apost bc if postsynaptic neuron fired shortly before, apost is negative so this decreases w = ltd;mimics biology:output fired before i did=my signal didn’t cause it=make this synapse a little weaker,corresponds to ltd driven by low ca2+/phosphatase activity
    ''',
    on_post='''
        apost += Apost                                 # each post-spike adds negative bump to post-trace to ensure this trace will trigger ltd later if pre-spike follows; mimics biology: postsynaptic neuron releases internal signals (ie: ca2+) that briefly mark synapse as recently active
        w = clip(w + eta*apre, 0, wmax)                # update weight using pre-trace (apre) that’s lingering from recent presynaptic activity, if pre-spike happened just before, apre is positive=ltp. mimics biology:input fired right before I did, it probably helped me fire, strengthen synapse=ltp via strong, rapid ca2+ influx
    ''',
    method='euler'                                     # “step-by-step” method; lets digital neuron change smoothly over simulated time=same way a real neuron’s voltage changes smoothly in real time; brian2 has different solvers for advancing time
)
# hebbian learning: synpases the fire together, wire together; if fired out of sync, they lose their link
# if during training connection repeatedly fires right before the correct output neuron, STDP will increase w (lap), if it fires out of sync, STDP will decrease w (ltd), over time, only input neurons that consistently help cause correct output spike keep high weights - forming the receptive field - not averaging
# while apre has residue from pre spike, the post spike happens, then when the network reaches on_post and sees apre > 0, it increases the weight=ltp; 
# without clipping, weights could grow infinitely if ltp keeps pushing them upward or become negative if LTD keeps pulling them downward; neurons would start firing nonstop, or connections could become inhibitory when they’re meant to be excitatory; mimics biology: real synapses also have limits (ie: can only insert so many receptor proteins, no “negative” synapses (either connects weakly or not at all), structural/molecular constraints set size of synapse)


# connectivity
S.connect(True)            # fully connect every input pixel to all three output neurons          
S.w = '0.002*rand()'       # start weights small + random                 
S.apre  = 0                # start traces at zero bc no actvity yet
S.apost = 0
    
# lateral inhibition; mimics the same concept in biology
ginh = 1*mV                           # size of inhibitory kick to other two neurons when one output neuron spikes
Sinhib = Synapses(OUT, OUT, on_pre='gi_post += ginh') # making new synapses that connect the output layer to itself, each output neuron can send inhibition to every other output neuron
Sinhib.connect(condition='i != j')    # build inhibitory synapses between all different pairs of output neurons, except where i == j: with itself
Sinhib.delay = 1*ms                   # transmission delay for inhibitory effect so it doesnt block the spike that triggered it, only subsequent ones

# monitors
spike_inp = SpikeMonitor(IN)                                    # count overall input spikes
spike_out = SpikeMonitor(OUT)                                   # count overall output spikes
rate_inp  = PopulationRateMonitor(IN)                           # track average firing rate of all input neurons over time
state_inp = StateMonitor(IN, 'rates', record=True)              # tracking stimulus intensity being fed into each sensory neuron
state_out = StateMonitor(OUT, ['v', 'ge', 'gi'], record=True)   # recording intracellular voltage trace + excitatory/inhibitory synaptic currents from real neuron w microelectrodes

# training loop
net = Network(collect())   # gather all variable into a single brian2 network object
teacher_amp = 6*mV         # amount of extra voltage/bias given to correct output neuron during stimulus/Ton

# running accuracy counters
correct = 0
seen = 0

for ep in range(epochs):
    order = np.random.permutation(len(imgs))  # shuffle image order each epoch to avoid learning by fixed order
    for k in order:
        # 1. set poisson rates for image to convert image into input firing rates; each pixel acts as sensory neuron firing at a rate proportional to how dark the spot is=spike-encoded version of visual scene: same way retina/lateral geniculate nucleus sends spike trains to primary visual cortex
        label_scalar = int(labels[k])
        IN.rates = img_to_rates(imgs[k])
        img_k = imgs[k]
        rates = IN.rates
        print("img stats:", img_k.min(), img_k.max(), "nonzero px:", np.count_nonzero(img_k))
        print("rate stats:", float((rates/Hz).min()), float((rates/Hz).max()))
        
        # 2. turn on teacher signal only for the correct output neuron; supervised learning in brain
        OUT.Iteach = 0*volt                        # clear any leftover bias
        OUT.Iteach[label_scalar] = teacher_amp     # apply voltage boost only to correct output neuron
        OUT.s = 0                                  # reset spike counters before trial
        # mimics biology: would be done by dopamine/other neuromodulators
        
        print('OUT has ge?', 'ge' in OUT.variables)
        if 'ge' in OUT.variables:
            print('ge unit:', OUT.variables['ge'].unit)
            print('ge mean (pre-run):', float(np.mean(OUT.ge)))

        print('w min/mean/max:', float(np.min(S.w)), float(np.mean(S.w)), float(np.max(S.w))) # snapshot of synaptic strength distribution in cortex before learning
        print('v start (mV):', list(np.round(OUT.v[:] / mV, 2)))
        print('vt (mV):', float(v_thr/mV))

        prev_spikes = spike_inp.num_spikes    # record how many spikes input layer has already emitted
        
        # 3. present image
        net.run(Ton)
        print("Δinput spikes:", spike_inp.num_spikes - prev_spikes)  # see how many new spikes occurred
        # represents when visual system actively perceiving stimulus (ie: eyes fixate on object for ~300 ms), during that retinal ganglion cells send spike trains, visual cortical neurons integrate those inputs, one output neuron fires first (“winner”), STDP strengthens causal pathways + weakens irrelevant ones

        # read per-neuron spike counts & pick answer
        counts = OUT.s[:]                 # ie: array([12, 1, 0])
        pred   = int(np.argmax(counts))   # index of neuron w most spikes, neuron that spikes most strongly “represents” object, similar to how real cortical neurons in primary visual cortex or IT (inferotemporal cortex) respond selectively to particular shapes/objects
        is_ok  = (pred == int(labels[k]))
        correct += int(is_ok)
        seen += 1
        print(f"img {k:02d} label={labels[k]} counts={counts} → pred={pred} {'✓' if is_ok else '✗'}")
        
        # 4. inter-stimulus: silence input & teacher; pause between stimuli, membrane potentials return to resting levels + ca2+ traces decay, so each new stimulus is fresh
        IN.rates   = 0*Hz
        OUT.Iteach[:] = 0*mV
        OUT.v  = v_rest
        OUT.ge = 0*mV
        OUT.gi = 0*mV
        S.apre = 0
        S.apost = 0
        net.run(Tisi)

    # epoch summary
    print(f"[epoch {ep+1}] running accuracy: {correct}/{seen} = {100*correct/seen:.1f}%")

    # normalisation; keeps total synaptic strength balanced so no neuron monopolises all weights
    if (ep + 1) % norm_every == 0:       
        i = np.array(S.i[:]); j = np.array(S.j[:])
        for out_idx in np.unique(j):                  
            idx = np.where(j == out_idx)[0]           # find all synapses that go into this output neuron
            total = float(np.sum(S.w[idx]))           # sum of its incoming weights
            if total > 0:                             # if nonzero, rescale weights so overall size is controlled
                S.w[idx] *= (1.0 / total)**0.5   
        print(f"[BDNF={BDNF_LEVEL}] soft-normalised incoming weights")

n_post = len(np.unique(S.j[:]))   
n_pre  = len(np.unique(S.i[:]))   

print("n_pre =", n_pre, "n_post =", n_post, "total weights =", len(S.w[:]))

# build (inputs x outputs) weight matrix for plotting
Wmat = np.zeros((n_pre, n_post))
for i, j, w in zip(S.i[:], S.j[:], S.w[:]):
    Wmat[i, j] = w

# for each output neuron, reshape weights back to image shape and save heatmap/receptive field
for k in range(n_post):
    fig, ax = plt.subplots()
    im = ax.imshow(Wmat[:, k].reshape(H, W))
    ax.set_title(f'OUT{k} receptive field')
    fig.colorbar(im, ax=ax)
    fig.tight_layout()

    out_png = Path(directory) / f"rf_OUT{k}.png"
    fig.savefig(out_png, dpi=150, bbox_inches="tight")
    print("saved:", out_png)

    plt.show()
# Out:
#   Skipped (not file or hidden)
# Found: 8.png
#   Loaded successfully
# Found: 9.png
#   Loaded successfully
# Found: 29.png
#   Loaded successfully
# Found: 21.png
#   Loaded successfully
# Found: 20.png
#   Loaded successfully
# Found: 22.png
#   Loaded successfully
# Found: 23.png
#   Loaded successfully
# Found: 25.png
#   Loaded successfully
# Found: 19.png
#   Loaded successfully
# Found: 4.png
#   Loaded successfully
# Found: 5.png
#   Loaded successfully
# Found: 7.png
#   Loaded successfully
# Found: 6.png
#   Loaded successfully
# Found: 2.png
#   Loaded successfully
# Found: 3.png
#   Loaded successfully
# Found: square 15.png
#   Loaded successfully
# Found: square 14.png
#   Loaded successfully
# Found: square 16.png
#   Loaded successfully
# Found: square 17.png
#   Loaded successfully
# Found: square 13.png
#   Loaded successfully
#   Skipped (not file or hidden)
# Found: square 9.png
#   Loaded successfully
# Found: square 11.png
#   Loaded successfully
# Found: square 20.png
#   Loaded successfully
# Found: square 7.png
#   Loaded successfully
# Found: square 6.png
#   Loaded successfully
# Found: square 21.png
#   Loaded successfully
# Found: square 4.png
#   Loaded successfully
# Found: square 22.png
#   Loaded successfully
# Found: square 5.png
#   Loaded successfully
# Found: square 25.png
#   Loaded successfully
# Found: triangle 20.png
#   Loaded successfully
# Found: triangle 22.png
#   Loaded successfully
# Found: triangle 23.png
#   Loaded successfully
#   Skipped (not file or hidden)
# Found: triangle 27.png
#   Loaded successfully
# Found: triangle 26.png
#   Loaded successfully
# Found: triangle 24.png
#   Loaded successfully
# Found: triangle 30.png
#   Loaded successfully
# Found: triangle 19.png
#   Loaded successfully
# Found: triangle 5.png
#   Loaded successfully
# Found: triangle 4.png
#   Loaded successfully
# Found: triangle 6.png
#   Loaded successfully
# Found: triangle 3.png
#   Loaded successfully
# Found: triangle 2.png
#   Loaded successfully
# Found: triangle 8.png
#   Loaded successfully
# Found: triangle 28.png
#   Loaded successfully
#
# Total images loaded: 45
# [BDNF=high_homeostatic] eta=0.0260, Apre=0.0165, Apost=-0.0152, norm_every=3
# img stats: 0.0 1.0 nonzero px: 6519
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 6.531092284256524e-08 0.00099589915556962 0.001999965981231441
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10740
# img 26 label=1 counts=[ 0 17  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6574
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0010175722160385174 0.0032979756380819487
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10530
# img 27 label=1 counts=[ 0 17  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 5644
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0010370574424467505 0.0042374567366790785
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 13372
# img 01 label=0 counts=[18  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 8067
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0010626920827192061 0.0042374567366790785
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5963
# img 36 label=2 counts=[ 0  0 15] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6363
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0010722122048610174 0.0042374567366790785
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10994
# img 28 label=1 counts=[ 0 18  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6379
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0010917808305882706 0.004657475705422729
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11191
# img 22 label=1 counts=[ 0 19  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6786
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0011147821962961373 0.005347119759135814
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10023
# img 24 label=1 counts=[ 0 19  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7975
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001133032152994961 0.006017448424640426
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6274
# img 35 label=2 counts=[ 0  0 16] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 7987
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0011452823660306455 0.006017448424640426
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6310
# img 34 label=2 counts=[ 0  0 16] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6340
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001155972989202864 0.006017448424640426
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11321
# img 12 label=0 counts=[18  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7742
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001177827216493632 0.006017448424640426
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 7094
# img 38 label=2 counts=[ 0  0 17] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 7987
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0011902773661843038 0.006017448424640426
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6462
# img 31 label=2 counts=[ 0  0 17] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 8011
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0012024720229314447 0.006017448424640426
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6120
# img 32 label=2 counts=[ 0  0 17] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6202
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0012126037571080224 0.0060999823244356505
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11789
# img 02 label=0 counts=[18  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6281
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0012313998800274873 0.0060999823244356505
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11790
# img 10 label=0 counts=[19  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6078
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0012519738412123654 0.0060999823244356505
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12127
# img 18 label=1 counts=[ 0 20  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6521
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0012745154530425858 0.006230646370102475
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10853
# img 07 label=0 counts=[19  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6324
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0012921075719403055 0.006230646370102475
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11435
# img 11 label=0 counts=[20  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6422
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0013155128231734613 0.0064376725483189495
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11038
# img 17 label=1 counts=[ 0 21  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6582
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0013418170924717411 0.007799957618637117
# v start (mV): [np.float64(-0.08), np.float64(0.0), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 10552
# img 21 label=1 counts=[ 0 21  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 8126
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0013625544608229657 0.008832420317456385
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5990
# img 44 label=2 counts=[ 0  0 17] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 8214
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0013709400445344453 0.008832420317456385
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5607
# img 37 label=2 counts=[ 0  0 17] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6221
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0013800948387752711 0.008832420317456385
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11549
# img 00 label=0 counts=[21  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6030
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0014053596141614041 0.008832420317456385
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12274
# img 08 label=0 counts=[22  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6356
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001432916929239547 0.008832420317456385
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11499
# img 05 label=0 counts=[22  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7814
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0014558617748858134 0.008832420317456385
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6911
# img 40 label=2 counts=[ 0  0 18] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6558
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0014679786853592288 0.008832420317456385
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10628
# img 15 label=1 counts=[ 0 21  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 8051
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0014889330068160159 0.009103712144388584
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6050
# img 33 label=2 counts=[ 0  0 18] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6373
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0014993472527631013 0.009103712144388584
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11042
# img 03 label=0 counts=[22  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 5944
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.00152081486466782 0.009103712144388584
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12565
# img 20 label=1 counts=[ 0 23  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7852
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001550112902078829 0.009030180151319166
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6645
# img 43 label=2 counts=[ 0  0 18] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 5788
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0015602483230733337 0.009030180151319166
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 13071
# img 13 label=0 counts=[24  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6056
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0015902120223880343 0.009030180151319166
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12270
# img 14 label=0 counts=[24  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6667
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0016156773098623368 0.009030180151319166
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10233
# img 19 label=1 counts=[ 0 22  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6454
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0016361812227260813 0.009030180151319166
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10999
# img 25 label=1 counts=[ 0 23  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 8097
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0016587145859415127 0.008965373957782295
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6019
# img 30 label=2 counts=[ 0  0 18] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6162
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0016684954754833884 0.008965373957782295
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11854
# img 04 label=0 counts=[24  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6365
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0016930377940243449 0.009071686571516361
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11259
# img 29 label=1 counts=[ 0 24  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7904
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0017166613755360712 0.009071686571516361
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6458
# img 41 label=2 counts=[ 0  0 19] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6591
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0017286501477229953 0.009071686571516361
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10444
# img 23 label=1 counts=[ 0 24  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7928
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0017511708104878884 0.009592785684958735
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6388
# img 42 label=2 counts=[ 0  0 19] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 5957
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001762030384097758 0.009592785684958735
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12268
# img 09 label=0 counts=[25  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7951
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001790120457730143 0.009592785684958735
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6252
# img 39 label=2 counts=[ 0  0 19] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6283
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0018007634557876252 0.009592785684958735
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11500
# img 06 label=0 counts=[26  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6384
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0018293493250400358 0.009592785684958735
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11095
# img 16 label=1 counts=[ 0 25  0] → pred=1 ✓
# [epoch 1] running accuracy: 45/45 = 100.0%
# img stats: 0.0 1.0 nonzero px: 6078
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0018557575588290512 0.00961906466620137
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12013
# img 18 label=1 counts=[ 0 27  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6365
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0018891731534334995 0.010112515040282316
# v start (mV): [np.float64(-0.08), np.float64(0.0), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 11267
# img 29 label=1 counts=[ 0 27  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 8051
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0019176477676417344 0.010547169536158554
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5913
# img 33 label=2 counts=[ 0  0 19] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6363
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0019274025945392793 0.010547169536158554
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11093
# img 28 label=1 counts=[ 0 27  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6030
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0019544868543206143 0.01088923073756374
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12247
# img 08 label=0 counts=[27  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7928
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0019856476637069493 0.01088923073756374
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6490
# img 42 label=2 counts=[ 0  0 20] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6221
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001998646810406412 0.01088923073756374
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11674
# img 00 label=0 counts=[28  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 8097
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0020316684661897573 0.01088923073756374
# v start (mV): [np.float64(0.0), np.float64(-0.08), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 5857
# img 30 label=2 counts=[ 0  0 20] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 7814
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002044003467363837 0.01088923073756374
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6947
# img 40 label=2 counts=[ 0  0 21] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6202
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0020570030918228175 0.01088923073756374
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11689
# img 02 label=0 counts=[29  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6422
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0020903986352753404 0.012166707905155288
# v start (mV): [np.float64(0.0), np.float64(-0.08), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 11111
# img 17 label=1 counts=[ 0 28  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6786
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002118379126221359 0.012166707905155288
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 9953
# img 24 label=1 counts=[ 0 27  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 5944
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0021425185255064894 0.012166707905155288
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12797
# img 20 label=1 counts=[ 0 31  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7951
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0021804252528403547 0.012166707905155288
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6422
# img 39 label=2 counts=[ 0  0 21] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6162
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002192838011063306 0.012166707905155288
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11643
# img 04 label=0 counts=[29  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6281
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0022224625932160008 0.011774911137326961
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11679
# img 10 label=0 counts=[29  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6519
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002251717414977161 0.012549890095620492
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10660
# img 26 label=1 counts=[ 0 29  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7852
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002278173757699166 0.012549890095620492
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6764
# img 43 label=2 counts=[ 0  0 22] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6384
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0022942033849921695 0.012549890095620492
# v start (mV): [np.float64(-0.08), np.float64(-0.08), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11159
# img 16 label=1 counts=[ 0 31  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6340
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002326976045851782 0.012549890095620492
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11398
# img 12 label=0 counts=[30  1  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7987
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0023598096120265874 0.012797261735513656
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6322
# img 31 label=2 counts=[ 0  0 22] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 5957
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0023745082436064367 0.012797261735513656
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12409
# img 09 label=0 counts=[32  3  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 8067
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0024138060689285045 0.013428877797785703
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5981
# img 36 label=2 counts=[ 0  0 22] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 8126
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002426711744922265 0.013428877797785703
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5759
# img 44 label=2 counts=[ 0  0 22] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 7742
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0024392606697163084 0.013428877797785703
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 7187
# img 38 label=2 counts=[ 0  0 23] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 5788
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0024550578985400194 0.013428877797785703
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 13177
# img 13 label=0 counts=[33  5  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6283
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0025015546350628443 0.013716906198673443
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11332
# img 06 label=0 counts=[33  1  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 5644
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0025402402931395123 0.014086922746311396
# v start (mV): [np.float64(0.0), np.float64(-0.08), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 13461
# img 01 label=0 counts=[36  4  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6454
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0025912372488837545 0.014679220492355212
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10942
# img 25 label=1 counts=[ 6 31  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6667
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0026284843413226194 0.014785053031728227
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10236
# img 19 label=1 counts=[ 5 31  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6324
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002661664501257306 0.014675130653392147
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11456
# img 11 label=0 counts=[34  5  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 8011
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0026998928848325486 0.014850630144233597
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6207
# img 32 label=2 counts=[ 0  0 23] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6591
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0027141299639605403 0.014850630144233597
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10461
# img 23 label=1 counts=[ 7 32  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6574
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002751418501571358 0.01492405034121917
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10513
# img 27 label=1 counts=[ 7 33  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6558
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002790943404769855 0.01531044170072333
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10689
# img 15 label=1 counts=[ 8 34  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6356
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002836663214099943 0.01598217475688921
# v start (mV): [np.float64(-0.08), np.float64(0.0), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 11526
# img 05 label=0 counts=[36  9  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6373
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0028830326236935037 0.01575789130482045
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11149
# img 03 label=0 counts=[36  8  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 8214
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.00292605814139997 0.01643627337158444
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5657
# img 37 label=2 counts=[ 0  0 23] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6056
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002939203374713008 0.01643627337158444
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12089
# img 14 label=0 counts=[37 10  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7975
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0029886629674765524 0.016835548202506354
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6192
# img 35 label=2 counts=[ 0  0 23] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 7987
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0030014053607429775 0.016835548202506354
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6166
# img 34 label=2 counts=[ 0  0 24] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6379
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0030159544845023505 0.016835548202506354
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11002
# img 22 label=1 counts=[12 35  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6521
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0030624256302580538 0.016835548202506354
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10795
# img 07 label=0 counts=[37  9  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6582
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0031062339160523623 0.016784634994591464
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10415
# img 21 label=1 counts=[12 36  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7904
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003153346369475216 0.017007528367952864
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6561
# img 41 label=2 counts=[ 0  0 24] → pred=2 ✓
# [epoch 2] running accuracy: 90/90 = 100.0%
# img stats: 0.0 1.0 nonzero px: 8011
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0031683733392642343 0.017007528367952864
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6268
# img 32 label=2 counts=[ 0  0 25] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6363
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003183562014934396 0.017007528367952864
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11159
# img 28 label=1 counts=[13 37  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6521
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0032306373452093986 0.017794232616073997
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10627
# img 07 label=0 counts=[38 11  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6667
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0032762651032786877 0.01793988430901961
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10154
# img 19 label=1 counts=[13 37  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6356
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0033264873752466818 0.01922885424578375
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11201
# img 05 label=0 counts=[41 13  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6574
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0033812319996295846 0.019441336591718
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10723
# img 27 label=1 counts=[15 39  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6373
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003435049826341185 0.01966422258308732
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11106
# img 03 label=0 counts=[42 14  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 8126
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003492000022794363 0.020191031162430317
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5942
# img 44 label=2 counts=[ 2  0 24] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6786
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0035061507806936542 0.020191031162430317
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 9791
# img 24 label=1 counts=[14 38  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 8097
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0035526765097271627 0.02095234758053839
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6037
# img 30 label=2 counts=[ 4  0 24] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 8051
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0035681252887568614 0.02095234758053839
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5995
# img 33 label=2 counts=[ 4  1 25] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6591
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0035853485721182867 0.02095234758053839
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10455
# img 23 label=1 counts=[17 41  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6281
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0036430307179043248 0.020861306114858928
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11604
# img 10 label=0 counts=[43 18  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7987
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0037060830301694886 0.021501431410938063
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6244
# img 31 label=2 counts=[ 6  4 25] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 7742
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0037274975304594513 0.021501431410938063
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 7094
# img 38 label=2 counts=[ 9  8 25] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6454
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.00375505557172431 0.021501431410938063
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10893
# img 25 label=1 counts=[19 42  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6365
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0038136570336266876 0.021862643563061536
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11308
# img 29 label=1 counts=[20 43  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7852
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003883228917842137 0.023422628121608495
# v start (mV): [np.float64(-0.08), np.float64(0.0), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 6767
# img 43 label=2 counts=[ 8  8 26] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 8067
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003911763498746436 0.023422628121608495
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5881
# img 36 label=2 counts=[ 6  5 25] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 8214
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0039323501030680596 0.023422628121608495
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5673
# img 37 label=2 counts=[ 4  4 26] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6078
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003952092177628146 0.023422628121608495
# v start (mV): [np.float64(-0.08), np.float64(-0.08), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12219
# img 18 label=1 counts=[22 46  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 5957
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004022855052767986 0.02393087510517312
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12541
# img 09 label=0 counts=[49 23  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7987
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004108068111494008 0.024402822047650524
# v start (mV): [np.float64(0.0), np.float64(-0.08), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 6297
# img 34 label=2 counts=[ 8  8 26] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6030
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0041306511947261796 0.024402822047650524
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12210
# img 08 label=0 counts=[49 23  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6221
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0042127010731204 0.02449654936462851
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11620
# img 00 label=0 counts=[49 23  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 5944
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004286417895077022 0.02446729762395857
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12623
# img 20 label=1 counts=[27 49  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6056
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0043744500353900375 0.025589954266689457
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12140
# img 14 label=0 counts=[49 26  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6202
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004459227210380998 0.025429652052440223
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11763
# img 02 label=0 counts=[49 26  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7975
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004536132057017115 0.02616385008070041
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6172
# img 35 label=2 counts=[12 10 26] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6283
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004565306956090489 0.026583096284483586
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11522
# img 06 label=0 counts=[49 27  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6519
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004646943398987591 0.02783710990863195
# v start (mV): [np.float64(-0.08), np.float64(0.0), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 10676
# img 26 label=1 counts=[27 49  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6324
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004717570464939859 0.027842829155256776
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11243
# img 11 label=0 counts=[49 28  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6162
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004796202502398604 0.0283755800758341
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11900
# img 04 label=0 counts=[49 30  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7814
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004878485264690874 0.02932057482566511
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6852
# img 40 label=2 counts=[17 15 25] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6582
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.00491506753821641 0.029222364715220873
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10405
# img 21 label=1 counts=[31 49  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6422
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.004990632593756294 0.029324475898014398
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11123
# img 17 label=1 counts=[33 49  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 5788
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.005070633225756952 0.029324475898014398
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 13103
# img 13 label=0 counts=[49 35  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7951
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.005168342547030219 0.030271448984929124
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6308
# img 39 label=2 counts=[17 15 25] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 5644
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0052016838977090064 0.030545434553057586
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 13185
# img 01 label=0 counts=[49 35  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6340
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.005301134265400489 0.030600064630933763
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11403
# img 12 label=0 counts=[49 34  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7928
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.005383908556661707 0.030375737613362378
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6425
# img 42 label=2 counts=[19 17 26] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6379
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.005422347370164217 0.03002569104357526
# v start (mV): [np.float64(-0.08), np.float64(-0.08), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11274
# img 22 label=1 counts=[39 49  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6558
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.005510197255683024 0.030132167144566978
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10530
# img 15 label=1 counts=[37 49  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7904
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.005589679562365003 0.03006897482589152
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6535
# img 41 label=2 counts=[21 19 25] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6384
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.00562587136878523 0.03070917833641766
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11183
# img 16 label=1 counts=[40 49  0] → pred=1 ✓
# [epoch 3] running accuracy: 135/135 = 100.0%
# [BDNF=high_homeostatic] soft-normalised incoming weights
# img stats: 0.0 1.0 nonzero px: 7814
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.000740203359984195 0.0036620467844848672
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6825
# img 40 label=2 counts=[ 0  0 17] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6030
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0007516720750969218 0.004135218188368746
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12202
# img 08 label=0 counts=[21  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 5944
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0007766933274124884 0.004633570021882842
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12549
# img 20 label=1 counts=[ 0 21  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6078
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0008024985392673866 0.004633570021882842
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12019
# img 18 label=1 counts=[ 0 21  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 8067
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0008265029943649477 0.005455008618714728
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6113
# img 36 label=2 counts=[ 0  0 17] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 8097
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0008357288006868186 0.005455008618714728
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6111
# img 30 label=2 counts=[ 0  0 17] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6379
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0008457559526465623 0.005455008618714728
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11102
# img 22 label=1 counts=[ 0 21  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6363
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0008659428391870694 0.005741469033122542
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11345
# img 28 label=1 counts=[ 0 22  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7987
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0008876118136374192 0.00623205409068544
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6313
# img 31 label=2 counts=[ 0  0 17] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 7951
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0008968796800480525 0.00623205409068544
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6205
# img 39 label=2 counts=[ 0  0 18] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6521
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0009078816041699602 0.00625157034818332
# ...
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0015555983221828575 0.011182054495092745
# v start (mV): [np.float64(-0.08), np.float64(-0.08), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11558
# img 10 label=0 counts=[29  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6454
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001587411520586006 0.011182054495092745
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11049
# img 25 label=1 counts=[ 0 29  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 5957
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0016166343302003018 0.011182054495092745
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12696
# img 09 label=0 counts=[30  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7852
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0016510330806857733 0.01180686186369155
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6616
# img 43 label=2 counts=[ 0  0 21] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6202
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0016638697203165782 0.01180686186369155
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11781
# img 02 label=0 counts=[30  0  0] → pred=0 ✓
# [epoch 4] running accuracy: 180/180 = 100.0%
# img stats: 0.0 1.0 nonzero px: 5788
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001694165632417123 0.012555867021771652
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 13196
# img 13 label=0 counts=[32  0  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7814
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0017322024448616223 0.013248919268112851
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6803
# img 40 label=2 counts=[ 0  0 21] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 8011
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0017440383649332967 0.013248919268112851
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6225
# img 32 label=2 counts=[ 0  0 21] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6667
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0017559979470173658 0.013248919268112851
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10202
# img 19 label=1 counts=[ 0 29  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6363
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0017828243362543628 0.013248919268112851
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11316
# img 28 label=1 counts=[ 1 30  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6454
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0018139580450647883 0.013250094490005776
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10885
# img 25 label=1 counts=[ 0 31  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6281
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0018444170191433927 0.013250094490005776
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11497
# img 10 label=0 counts=[32  2  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6591
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0018799935000378336 0.014064343303861932
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10420
# img 23 label=1 counts=[ 0 32  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6221
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.001912516014369357 0.014064343303861932
# v start (mV): [np.float64(-0.08), np.float64(0.0), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 11618
# img 00 label=0 counts=[32  4  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6422
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0019500328588400112 0.013792067162275387
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10935
# img 17 label=1 counts=[ 3 32  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6283
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0019839284870377155 0.013792067162275387
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11462
# img 06 label=0 counts=[33  6  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 8097
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002028429276057546 0.014686456708545122
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6032
# img 30 label=2 counts=[ 0  0 21] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 7987
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002039998353093628 0.014686456708545122
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6130
# img 34 label=2 counts=[ 0  0 22] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 7975
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0020526113969438764 0.014686456708545122
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6403
# img 35 label=2 counts=[ 0  0 22] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6324
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002065118159580886 0.014686456708545122
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11527
# img 11 label=0 counts=[33  7  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 8067
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0021089417410853845 0.01468162072856426
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6002
# img 36 label=2 counts=[ 0  0 23] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 8126
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0021231789791945287 0.01468162072856426
# v start (mV): [np.float64(-0.08), np.float64(-0.08), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 5845
# img 44 label=2 counts=[ 0  0 22] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 5944
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002133583684712358 0.01468162072856426
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12697
# img 20 label=1 counts=[ 9 34  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 8051
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0021860635634747424 0.015118282430175928
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6008
# img 33 label=2 counts=[ 0  0 23] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 5644
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0021977512608217305 0.015118282430175928
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 13528
# img 01 label=0 counts=[36  9  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6574
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0022529120130655484 0.014926663805461541
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10637
# img 27 label=1 counts=[ 8 33  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6356
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0022912397313400133 0.015409155820095595
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11434
# img 05 label=0 counts=[36  9  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6521
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002339206987982597 0.015822440258678735
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10898
# img 07 label=0 counts=[36  8  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6373
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002381211508449918 0.015783011706843094
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11076
# img 03 label=0 counts=[37  8  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 5957
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.00242928955936957 0.015678992132017053
# v start (mV): [np.float64(0.0), np.float64(-0.08), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 12358
# img 09 label=0 counts=[38 10  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6558
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0024823426776372534 0.01655869579724436
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10692
# img 15 label=1 counts=[12 35  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7852
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002526165828494381 0.016799265405517093
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6549
# img 43 label=2 counts=[ 0  0 24] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6162
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0025424090906592096 0.016799265405517093
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12023
# img 04 label=0 counts=[41 11  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6582
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0025978474516247228 0.017564735337282686
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10491
# img 21 label=1 counts=[13 37  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6365
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0026483549013518494 0.01765310947429626
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11348
# img 29 label=1 counts=[14 37  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6379
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002702157059823552 0.018373019486142582
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11143
# img 22 label=1 counts=[15 37  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7987
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0027530880716189 0.018346193647853993
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6391
# img 31 label=2 counts=[ 3  1 23] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6384
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0027697717288339466 0.018346193647853993
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11081
# img 16 label=1 counts=[15 39  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 7928
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.002824180898005172 0.01812312704108875
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6491
# img 42 label=2 counts=[ 4  3 24] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6519
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.00284462904341171 0.01831549080865569
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 10768
# img 26 label=1 counts=[15 40  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6030
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0029031852978243116 0.01825865592020007
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12237
# img 08 label=0 counts=[42 17  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 6078
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0029705988504071324 0.018594189980235338
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12139
# img 18 label=1 counts=[19 42  0] → pred=1 ✓
# img stats: 0.0 1.0 nonzero px: 6202
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003037987839379895 0.018869719502158495
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11604
# img 02 label=0 counts=[42 18  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7951
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0031013457894611953 0.019460407959664434
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6180
# img 39 label=2 counts=[ 5  5 23] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 7742
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0031204813676359985 0.0195673781623662
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 7138
# img 38 label=2 counts=[ 9  8 24] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6056
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003149308909909311 0.020168494345770796
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 12229
# img 14 label=0 counts=[45 19  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 8214
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003224170351537575 0.021024819286020836
# v start (mV): [np.float64(0.0), np.float64(-0.08), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 5603
# img 37 label=2 counts=[ 4  2 24] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6340
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003240979385457461 0.020991615478562164
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 11296
# img 12 label=0 counts=[46 19  0] → pred=0 ✓
# img stats: 0.0 1.0 nonzero px: 7904
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.0033105391768325863 0.02125689547226271
# v start (mV): [np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# vt (mV): 4.0
# Δinput spikes: 6439
# img 41 label=2 counts=[ 9  7 24] → pred=2 ✓
# img stats: 0.0 1.0 nonzero px: 6786
# rate stats: 0.0 10.0
# OUT has ge? True
# ge unit: V
# ge mean (pre-run): 0.0
# w min/mean/max: 0.0 0.003338373047836667 0.021740058851291537
# v start (mV): [np.float64(0.0), np.float64(-0.08), np.float64(-0.08)]
# vt (mV): 4.0
# Δinput spikes: 9848
# img 24 label=1 counts=[18 42  0] → pred=1 ✓
# [epoch 5] running accuracy: 225/225 = 100.0%
# n_pre = 10000 n_post = 3 total weights = 30000
# saved: STDP_homeostatic_high_epoh_never_test/rf_OUT0.png
# saved: STDP_homeostatic_high_epoh_never_test/rf_OUT1.png
# saved: STDP_homeostatic_high_epoh_never_test/rf_OUT2.png

# %%
subplot(311)
plot(S.w / wmax, '.k')
ylabel('Weight / wmax')
xlabel('Synapse index')
subplot(312)
hist(S.w / wmax, 20)
xlabel('Weight / wmax')
subplot(313)
plot(state_out.t/second, state_out.v[0]/mV)
vlines(spike_out.t/second, ymin=0, ymax=5, color='r', alpha=0.3)
xlim(0.5, 1.5)
xlabel('Time (s)')
ylabel('Membrane potential (mV)')
fig, ax = plt.subplots(3, 1, sharex=True, figsize=(7,6))

ax[0].plot(state_out.t/second, state_out.v[0]/mV)
ax[0].set_ylabel('v (mV)')
plt.xlim(0.5, 1.5)

ax[1].plot(state_out.t/second, state_out.ge[0]/mV)   
ax[1].set_ylabel('ge (mV)')
plt.xlim(0.5, 1.5)

ax[2].plot(state_out.t/second, state_out.gi[0]/mV)   
ax[2].set_ylabel('gi (mV)')
ax[2].set_xlabel('Time (s)')
plt.xlim(0.5, 1.5)

#tight_layout()
show()
